# %% [markdown]
# ## Prepare the data

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import davies_bouldin_score
import matplotlib.pyplot as plt
import pandas as pd 
import json 

data = pd.read_csv('../data/codebooks/collusion-semantic-seg-llama31-70b-tags-llama31-70b-codebook.csv')
tag_embeddings = {}

for ind,row in data.iterrows():
    tag_embeddings[row['tag']] = json.loads(row['embeddings'])

# Convert dictionary to an array of embeddings
embeddings = np.array(list(tag_embeddings.values()))
# print(len(embeddings[0]))
data.head()
# Out:
#    Unnamed: 0                          tag  \
# 0           0      exam marking discussion
# 1           1  professional interview tone
# 2           2        neutral job candidate
# 3           3          formal conversation
# 4           4          academic discussion
#
#                                          description  \
# 0  "A conversation about the process and methods ...
# 1  "A formal and polished conversation between tw...
# 2  "A discussion where one participant's response...
# 3  "A polite and professional discussion between ...
# 4  "A serious and informative conversation betwee...
#
#                                           embeddings
# 0  [0.32319629192352295, -0.17829398810863495, -0...
# 1  [0.3332962691783905, -0.046114273369312286, 0....
# 2  [0.1742410808801651, -0.060671158134937286, -0...
# 3  [0.4877059757709503, 0.031197376549243927, -0....
# 4  [0.3865499794483185, -0.04310765117406845, -0....

# %% [markdown]
# # Compute ideal dimensional reduction - looking for score of 90-95% meaning that much variation has been explained

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Define a range of PCA components to test
pca_components = [10, 20, 50, 100, 200, 300]  # Adjust as needed for your dataset

# Dictionary to store cumulative explained variance for each component count
explained_variances = {}

# Loop over each number of components
for n_components in pca_components:
    # Apply PCA with n_components
    pca = PCA(n_components=n_components)
    pca.fit(embeddings)  # 'embeddings' should be your dataset of vectors

    # Calculate cumulative explained variance
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)[-1]  # Total explained variance for n_components
    explained_variances[n_components] = cumulative_variance
    print(f"PCA components: {n_components}, Cumulative explained variance: {cumulative_variance:.4f}")

# Plot cumulative explained variance
plt.figure(figsize=(10, 6))
plt.plot(list(explained_variances.keys()), list(explained_variances.values()), marker='o')
plt.xlabel('Number of PCA Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance vs Number of PCA Components')
plt.grid(True)
plt.show()
# Out:
# PCA components: 10, Cumulative explained variance: 0.5030
# PCA components: 20, Cumulative explained variance: 0.6567
# PCA components: 50, Cumulative explained variance: 0.8354
# PCA components: 100, Cumulative explained variance: 0.9333
# PCA components: 200, Cumulative explained variance: 0.9866
# PCA components: 300, Cumulative explained variance: 0.9984

# %%
pca_dimensions = [100] # pca dimnesions

# %% [markdown]
# # pca_dimensions = [100] # pca dimnesions

# %%
from sklearn import preprocessing
from sklearn.cluster import KMeans


# Experiment parameters
cluster_range = range(2,100)        # Range of k values for clustering

# Dictionary to store results
results = {}


# Apply PCA to reduce dimensions
pca = PCA(n_components=dim)
reduced_embeddings = pca.fit_transform(embeddings)
normed_embeddings = preprocessing.normalize(reduced_embeddings)

for dim in pca_dimensions:
    print(f"Doing PCA of {dim} embeddings d is {len(embeddings[0])}")
    # Dictionary to store Davies-Bouldin scores for each k in the current PCA dimension
    results[dim] = {}
    
    # Loop over each number of clusters (k)
    for k in cluster_range:
        # Apply KMeans clustering
        # kmeans = KMeans(n_clusters=k, random_state=0)
        # cluster_labels = kmeans.fit_predict(reduced_embeddings)
    
        kmeans = KMeans(n_clusters=k, random_state=0)
        cluster_labels = kmeans.fit_predict(normed_embeddings)
        
        # Calculate Davies-Bouldin Index
        db_index = davies_bouldin_score(reduced_embeddings, cluster_labels)
        results[dim][k] = db_index
        print(f"PCA Dim: {dim}, Clusters: {k}, Davies-Bouldin Index: {db_index:.3f}")
# Out:
# Doing PCA of 100 embeddings d is 1024
# PCA Dim: 100, Clusters: 2, Davies-Bouldin Index: 2.882
# PCA Dim: 100, Clusters: 3, Davies-Bouldin Index: 2.662
# PCA Dim: 100, Clusters: 4, Davies-Bouldin Index: 2.992
# PCA Dim: 100, Clusters: 5, Davies-Bouldin Index: 2.866
# PCA Dim: 100, Clusters: 6, Davies-Bouldin Index: 2.864
# PCA Dim: 100, Clusters: 7, Davies-Bouldin Index: 2.862
# PCA Dim: 100, Clusters: 8, Davies-Bouldin Index: 2.843
# PCA Dim: 100, Clusters: 9, Davies-Bouldin Index: 2.748
# PCA Dim: 100, Clusters: 10, Davies-Bouldin Index: 2.832
# PCA Dim: 100, Clusters: 11, Davies-Bouldin Index: 2.750
# PCA Dim: 100, Clusters: 12, Davies-Bouldin Index: 2.736
# PCA Dim: 100, Clusters: 13, Davies-Bouldin Index: 2.655
# PCA Dim: 100, Clusters: 14, Davies-Bouldin Index: 2.605
# PCA Dim: 100, Clusters: 15, Davies-Bouldin Index: 2.531
# PCA Dim: 100, Clusters: 16, Davies-Bouldin Index: 2.498
# PCA Dim: 100, Clusters: 17, Davies-Bouldin Index: 2.560
# PCA Dim: 100, Clusters: 18, Davies-Bouldin Index: 2.548
# PCA Dim: 100, Clusters: 19, Davies-Bouldin Index: 2.579
# PCA Dim: 100, Clusters: 20, Davies-Bouldin Index: 2.494
# PCA Dim: 100, Clusters: 21, Davies-Bouldin Index: 2.485
# PCA Dim: 100, Clusters: 22, Davies-Bouldin Index: 2.476
# PCA Dim: 100, Clusters: 23, Davies-Bouldin Index: 2.476
# PCA Dim: 100, Clusters: 24, Davies-Bouldin Index: 2.409
# PCA Dim: 100, Clusters: 25, Davies-Bouldin Index: 2.396
# PCA Dim: 100, Clusters: 26, Davies-Bouldin Index: 2.402
# PCA Dim: 100, Clusters: 27, Davies-Bouldin Index: 2.432
# PCA Dim: 100, Clusters: 28, Davies-Bouldin Index: 2.433
# PCA Dim: 100, Clusters: 29, Davies-Bouldin Index: 2.395
# PCA Dim: 100, Clusters: 30, Davies-Bouldin Index: 2.343
# PCA Dim: 100, Clusters: 31, Davies-Bouldin Index: 2.303
# PCA Dim: 100, Clusters: 32, Davies-Bouldin Index: 2.266
# PCA Dim: 100, Clusters: 33, Davies-Bouldin Index: 2.262
# PCA Dim: 100, Clusters: 34, Davies-Bouldin Index: 2.240
# PCA Dim: 100, Clusters: 35, Davies-Bouldin Index: 2.235
# PCA Dim: 100, Clusters: 36, Davies-Bouldin Index: 2.251
# PCA Dim: 100, Clusters: 37, Davies-Bouldin Index: 2.226
# PCA Dim: 100, Clusters: 38, Davies-Bouldin Index: 2.203
# PCA Dim: 100, Clusters: 39, Davies-Bouldin Index: 2.168
# PCA Dim: 100, Clusters: 40, Davies-Bouldin Index: 2.161
# PCA Dim: 100, Clusters: 41, Davies-Bouldin Index: 2.171
# PCA Dim: 100, Clusters: 42, Davies-Bouldin Index: 2.177
# PCA Dim: 100, Clusters: 43, Davies-Bouldin Index: 2.157
# PCA Dim: 100, Clusters: 44, Davies-Bouldin Index: 2.153
# PCA Dim: 100, Clusters: 45, Davies-Bouldin Index: 2.130
# PCA Dim: 100, Clusters: 46, Davies-Bouldin Index: 2.083
# PCA Dim: 100, Clusters: 47, Davies-Bouldin Index: 2.068
# PCA Dim: 100, Clusters: 48, Davies-Bouldin Index: 2.030
# PCA Dim: 100, Clusters: 49, Davies-Bouldin Index: 2.015
# PCA Dim: 100, Clusters: 50, Davies-Bouldin Index: 1.990
# PCA Dim: 100, Clusters: 51, Davies-Bouldin Index: 1.974
# PCA Dim: 100, Clusters: 52, Davies-Bouldin Index: 1.962
# PCA Dim: 100, Clusters: 53, Davies-Bouldin Index: 1.952
# PCA Dim: 100, Clusters: 54, Davies-Bouldin Index: 1.943
# PCA Dim: 100, Clusters: 55, Davies-Bouldin Index: 1.921
# PCA Dim: 100, Clusters: 56, Davies-Bouldin Index: 1.909
# PCA Dim: 100, Clusters: 57, Davies-Bouldin Index: 1.898
# PCA Dim: 100, Clusters: 58, Davies-Bouldin Index: 1.861
# PCA Dim: 100, Clusters: 59, Davies-Bouldin Index: 1.856
# PCA Dim: 100, Clusters: 60, Davies-Bouldin Index: 1.831
# PCA Dim: 100, Clusters: 61, Davies-Bouldin Index: 1.818
# PCA Dim: 100, Clusters: 62, Davies-Bouldin Index: 1.807
# PCA Dim: 100, Clusters: 63, Davies-Bouldin Index: 1.798
# PCA Dim: 100, Clusters: 64, Davies-Bouldin Index: 1.772
# PCA Dim: 100, Clusters: 65, Davies-Bouldin Index: 1.759
# PCA Dim: 100, Clusters: 66, Davies-Bouldin Index: 1.756
# PCA Dim: 100, Clusters: 67, Davies-Bouldin Index: 1.736
# PCA Dim: 100, Clusters: 68, Davies-Bouldin Index: 1.721
# PCA Dim: 100, Clusters: 69, Davies-Bouldin Index: 1.714
# PCA Dim: 100, Clusters: 70, Davies-Bouldin Index: 1.703
# PCA Dim: 100, Clusters: 71, Davies-Bouldin Index: 1.689
# PCA Dim: 100, Clusters: 72, Davies-Bouldin Index: 1.689
# PCA Dim: 100, Clusters: 73, Davies-Bouldin Index: 1.679
# PCA Dim: 100, Clusters: 74, Davies-Bouldin Index: 1.662
# PCA Dim: 100, Clusters: 75, Davies-Bouldin Index: 1.659
# PCA Dim: 100, Clusters: 76, Davies-Bouldin Index: 1.649
# PCA Dim: 100, Clusters: 77, Davies-Bouldin Index: 1.650
# PCA Dim: 100, Clusters: 78, Davies-Bouldin Index: 1.642
# PCA Dim: 100, Clusters: 79, Davies-Bouldin Index: 1.635
# PCA Dim: 100, Clusters: 80, Davies-Bouldin Index: 1.615
# PCA Dim: 100, Clusters: 81, Davies-Bouldin Index: 1.609
# PCA Dim: 100, Clusters: 82, Davies-Bouldin Index: 1.594
# PCA Dim: 100, Clusters: 83, Davies-Bouldin Index: 1.605
# PCA Dim: 100, Clusters: 84, Davies-Bouldin Index: 1.590
# PCA Dim: 100, Clusters: 85, Davies-Bouldin Index: 1.572
# PCA Dim: 100, Clusters: 86, Davies-Bouldin Index: 1.556
# PCA Dim: 100, Clusters: 87, Davies-Bouldin Index: 1.543
# PCA Dim: 100, Clusters: 88, Davies-Bouldin Index: 1.536
# PCA Dim: 100, Clusters: 89, Davies-Bouldin Index: 1.519
# PCA Dim: 100, Clusters: 90, Davies-Bouldin Index: 1.508
# PCA Dim: 100, Clusters: 91, Davies-Bouldin Index: 1.498
# PCA Dim: 100, Clusters: 92, Davies-Bouldin Index: 1.487
# PCA Dim: 100, Clusters: 93, Davies-Bouldin Index: 1.475
# PCA Dim: 100, Clusters: 94, Davies-Bouldin Index: 1.466
# PCA Dim: 100, Clusters: 95, Davies-Bouldin Index: 1.468
# PCA Dim: 100, Clusters: 96, Davies-Bouldin Index: 1.465
# PCA Dim: 100, Clusters: 97, Davies-Bouldin Index: 1.454
# PCA Dim: 100, Clusters: 98, Davies-Bouldin Index: 1.445
# PCA Dim: 100, Clusters: 99, Davies-Bouldin Index: 1.436

# %% [markdown]
# # compute silhouette and davies bouldin scores for different k

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import davies_bouldin_score, silhouette_score
import numpy as np

# Experiment parameters
dim = 200
cluster_range = range(2, 100)        # Range of k values for clustering

# Dictionary to store results
results = {}

# Loop over each PCA dimension
for dim in pca_dimensions:
    # Apply PCA to reduce dimensions
    print(f"Doing PCA of {dim} embeddings where initial dimension is {len(embeddings[0])}")
    pca = PCA(n_components=dim)
    reduced_embeddings = pca.fit_transform(embeddings)

    # Dictionary to store Davies-Bouldin and Silhouette scores for each k
    results[dim] = {'davies_bouldin': {}, 'silhouette': {}}

    # Loop over each number of clusters (k)
    for k in cluster_range:
        # Apply KMeans clustering
        kmeans = KMeans(n_clusters=k, random_state=0)
        cluster_labels = kmeans.fit_predict(reduced_embeddings)

        # Calculate Davies-Bouldin Index
        db_index = davies_bouldin_score(reduced_embeddings, cluster_labels)
        results[dim]['davies_bouldin'][k] = db_index
        
        # Calculate Silhouette Score (only if k > 1)
        if k > 1:
            silhouette_avg = silhouette_score(reduced_embeddings, cluster_labels)
            results[dim]['silhouette'][k] = silhouette_avg
        else:
            results[dim]['silhouette'][k] = None  # No Silhouette Score for k=1

        print(f"PCA Dim: {dim}, Clusters: {k}, DB Index: {db_index:.3f}, Silhouette Score: {silhouette_avg:.3f}" if k > 1 else f"PCA Dim: {dim}, Clusters: {k}, DB Index: {db_index:.3f}")

# Results dictionary now contains both Davies-Bouldin and Silhouette scores for each PCA dimension and cluster count
# Out:
# Doing PCA of 100 embeddings where initial dimension is 1024
# PCA Dim: 100, Clusters: 2, DB Index: 2.075, Silhouette Score: 0.152
# PCA Dim: 100, Clusters: 3, DB Index: 2.661, Silhouette Score: 0.091
# PCA Dim: 100, Clusters: 4, DB Index: 2.791, Silhouette Score: 0.081
# PCA Dim: 100, Clusters: 5, DB Index: 2.892, Silhouette Score: 0.078
# PCA Dim: 100, Clusters: 6, DB Index: 2.704, Silhouette Score: 0.082
# PCA Dim: 100, Clusters: 7, DB Index: 2.622, Silhouette Score: 0.090
# PCA Dim: 100, Clusters: 8, DB Index: 2.756, Silhouette Score: 0.082
# PCA Dim: 100, Clusters: 9, DB Index: 2.622, Silhouette Score: 0.082
# PCA Dim: 100, Clusters: 10, DB Index: 2.547, Silhouette Score: 0.085
# PCA Dim: 100, Clusters: 11, DB Index: 2.650, Silhouette Score: 0.082
# PCA Dim: 100, Clusters: 12, DB Index: 2.547, Silhouette Score: 0.080
# PCA Dim: 100, Clusters: 13, DB Index: 2.533, Silhouette Score: 0.074
# PCA Dim: 100, Clusters: 14, DB Index: 2.553, Silhouette Score: 0.074
# PCA Dim: 100, Clusters: 15, DB Index: 2.554, Silhouette Score: 0.070
# PCA Dim: 100, Clusters: 16, DB Index: 2.539, Silhouette Score: 0.075
# PCA Dim: 100, Clusters: 17, DB Index: 2.546, Silhouette Score: 0.069
# PCA Dim: 100, Clusters: 18, DB Index: 2.448, Silhouette Score: 0.077
# PCA Dim: 100, Clusters: 19, DB Index: 2.385, Silhouette Score: 0.074
# PCA Dim: 100, Clusters: 20, DB Index: 2.359, Silhouette Score: 0.076
# PCA Dim: 100, Clusters: 21, DB Index: 2.570, Silhouette Score: 0.065
# PCA Dim: 100, Clusters: 22, DB Index: 2.567, Silhouette Score: 0.062
# PCA Dim: 100, Clusters: 23, DB Index: 2.503, Silhouette Score: 0.062
# PCA Dim: 100, Clusters: 24, DB Index: 2.463, Silhouette Score: 0.059
# PCA Dim: 100, Clusters: 25, DB Index: 2.410, Silhouette Score: 0.060
# PCA Dim: 100, Clusters: 26, DB Index: 2.388, Silhouette Score: 0.060
# PCA Dim: 100, Clusters: 27, DB Index: 2.430, Silhouette Score: 0.058
# PCA Dim: 100, Clusters: 28, DB Index: 2.380, Silhouette Score: 0.059
# PCA Dim: 100, Clusters: 29, DB Index: 2.354, Silhouette Score: 0.060
# PCA Dim: 100, Clusters: 30, DB Index: 2.327, Silhouette Score: 0.062
# PCA Dim: 100, Clusters: 31, DB Index: 2.312, Silhouette Score: 0.065
# PCA Dim: 100, Clusters: 32, DB Index: 2.264, Silhouette Score: 0.067
# PCA Dim: 100, Clusters: 33, DB Index: 2.259, Silhouette Score: 0.069
# PCA Dim: 100, Clusters: 34, DB Index: 2.248, Silhouette Score: 0.068
# PCA Dim: 100, Clusters: 35, DB Index: 2.200, Silhouette Score: 0.067
# PCA Dim: 100, Clusters: 36, DB Index: 2.182, Silhouette Score: 0.068
# PCA Dim: 100, Clusters: 37, DB Index: 2.174, Silhouette Score: 0.068
# PCA Dim: 100, Clusters: 38, DB Index: 2.182, Silhouette Score: 0.068
# PCA Dim: 100, Clusters: 39, DB Index: 2.147, Silhouette Score: 0.070
# PCA Dim: 100, Clusters: 40, DB Index: 2.134, Silhouette Score: 0.071
# PCA Dim: 100, Clusters: 41, DB Index: 2.120, Silhouette Score: 0.069
# PCA Dim: 100, Clusters: 42, DB Index: 2.081, Silhouette Score: 0.071
# PCA Dim: 100, Clusters: 43, DB Index: 2.051, Silhouette Score: 0.075
# PCA Dim: 100, Clusters: 44, DB Index: 2.020, Silhouette Score: 0.075
# PCA Dim: 100, Clusters: 45, DB Index: 2.042, Silhouette Score: 0.071
# PCA Dim: 100, Clusters: 46, DB Index: 2.031, Silhouette Score: 0.071
# PCA Dim: 100, Clusters: 47, DB Index: 2.005, Silhouette Score: 0.071
# PCA Dim: 100, Clusters: 48, DB Index: 1.997, Silhouette Score: 0.069
# PCA Dim: 100, Clusters: 49, DB Index: 2.002, Silhouette Score: 0.069
# PCA Dim: 100, Clusters: 50, DB Index: 1.986, Silhouette Score: 0.069
# PCA Dim: 100, Clusters: 51, DB Index: 1.974, Silhouette Score: 0.068
# PCA Dim: 100, Clusters: 52, DB Index: 1.944, Silhouette Score: 0.067
# PCA Dim: 100, Clusters: 53, DB Index: 1.914, Silhouette Score: 0.066
# PCA Dim: 100, Clusters: 54, DB Index: 1.904, Silhouette Score: 0.065
# PCA Dim: 100, Clusters: 55, DB Index: 1.831, Silhouette Score: 0.075
# PCA Dim: 100, Clusters: 56, DB Index: 1.808, Silhouette Score: 0.076
# PCA Dim: 100, Clusters: 57, DB Index: 1.809, Silhouette Score: 0.074
# PCA Dim: 100, Clusters: 58, DB Index: 1.800, Silhouette Score: 0.076
# PCA Dim: 100, Clusters: 59, DB Index: 1.824, Silhouette Score: 0.074
# PCA Dim: 100, Clusters: 60, DB Index: 1.821, Silhouette Score: 0.073
# PCA Dim: 100, Clusters: 61, DB Index: 1.828, Silhouette Score: 0.074
# PCA Dim: 100, Clusters: 62, DB Index: 1.823, Silhouette Score: 0.073
# PCA Dim: 100, Clusters: 63, DB Index: 1.804, Silhouette Score: 0.073
# PCA Dim: 100, Clusters: 64, DB Index: 1.781, Silhouette Score: 0.073
# PCA Dim: 100, Clusters: 65, DB Index: 1.757, Silhouette Score: 0.074
# PCA Dim: 100, Clusters: 66, DB Index: 1.754, Silhouette Score: 0.074
# PCA Dim: 100, Clusters: 67, DB Index: 1.737, Silhouette Score: 0.074
# PCA Dim: 100, Clusters: 68, DB Index: 1.719, Silhouette Score: 0.075
# PCA Dim: 100, Clusters: 69, DB Index: 1.704, Silhouette Score: 0.077
# PCA Dim: 100, Clusters: 70, DB Index: 1.683, Silhouette Score: 0.077
# PCA Dim: 100, Clusters: 71, DB Index: 1.674, Silhouette Score: 0.078
# PCA Dim: 100, Clusters: 72, DB Index: 1.658, Silhouette Score: 0.076
# PCA Dim: 100, Clusters: 73, DB Index: 1.637, Silhouette Score: 0.077
# PCA Dim: 100, Clusters: 74, DB Index: 1.642, Silhouette Score: 0.077
# PCA Dim: 100, Clusters: 75, DB Index: 1.624, Silhouette Score: 0.078
# PCA Dim: 100, Clusters: 76, DB Index: 1.608, Silhouette Score: 0.078
# PCA Dim: 100, Clusters: 77, DB Index: 1.609, Silhouette Score: 0.078
# PCA Dim: 100, Clusters: 78, DB Index: 1.586, Silhouette Score: 0.078
# PCA Dim: 100, Clusters: 79, DB Index: 1.586, Silhouette Score: 0.079
# PCA Dim: 100, Clusters: 80, DB Index: 1.576, Silhouette Score: 0.079
# PCA Dim: 100, Clusters: 81, DB Index: 1.572, Silhouette Score: 0.080
# PCA Dim: 100, Clusters: 82, DB Index: 1.564, Silhouette Score: 0.080
# PCA Dim: 100, Clusters: 83, DB Index: 1.564, Silhouette Score: 0.081
# PCA Dim: 100, Clusters: 84, DB Index: 1.558, Silhouette Score: 0.080
# PCA Dim: 100, Clusters: 85, DB Index: 1.542, Silhouette Score: 0.080
# PCA Dim: 100, Clusters: 86, DB Index: 1.539, Silhouette Score: 0.080
# PCA Dim: 100, Clusters: 87, DB Index: 1.527, Silhouette Score: 0.081
# PCA Dim: 100, Clusters: 88, DB Index: 1.514, Silhouette Score: 0.079
# PCA Dim: 100, Clusters: 89, DB Index: 1.497, Silhouette Score: 0.079
# PCA Dim: 100, Clusters: 90, DB Index: 1.482, Silhouette Score: 0.080
# PCA Dim: 100, Clusters: 91, DB Index: 1.476, Silhouette Score: 0.082
# PCA Dim: 100, Clusters: 92, DB Index: 1.460, Silhouette Score: 0.082
# PCA Dim: 100, Clusters: 93, DB Index: 1.458, Silhouette Score: 0.082
# PCA Dim: 100, Clusters: 94, DB Index: 1.445, Silhouette Score: 0.084
# PCA Dim: 100, Clusters: 95, DB Index: 1.440, Silhouette Score: 0.086
# PCA Dim: 100, Clusters: 96, DB Index: 1.425, Silhouette Score: 0.084
# PCA Dim: 100, Clusters: 97, DB Index: 1.414, Silhouette Score: 0.086
# PCA Dim: 100, Clusters: 98, DB Index: 1.410, Silhouette Score: 0.085
# PCA Dim: 100, Clusters: 99, DB Index: 1.401, Silhouette Score: 0.087

# %% [markdown]
# # Plot scores : want low DB and high sihlouette (close to 1 is good here)

# %%
import matplotlib.pyplot as plt

# Plot Davies-Bouldin Index
plt.figure(figsize=(12, 8))
for dim in pca_dimensions:
    x_values = list(results[dim]['davies_bouldin'].keys())
    y_values = list(results[dim]['davies_bouldin'].values())
    
    # Plot the Davies-Bouldin Index for each dimension
    plt.plot(x_values, y_values, marker='o', label=f'PCA {dim} dims')
    
    # Add labels with arrows pointing to the last point in each line
    plt.annotate(f'PCA {dim} dims',
                 xy=(x_values[-1], y_values[-1]),               # Last point coordinates
                 xytext=(x_values[-1] + 0.5, y_values[-1]),     # Offset the text slightly
                 arrowprops=dict(arrowstyle="->", lw=1.5))

plt.xlabel('Number of Clusters (k)')
plt.ylabel('Davies-Bouldin Index')
plt.title('Davies-Bouldin Index vs Number of Clusters for Different PCA Dimensions')
plt.legend()
plt.grid(True)
plt.show()

# Plot Silhouette Score
plt.figure(figsize=(12, 8))
for dim in pca_dimensions:
    x_values = list(results[dim]['silhouette'].keys())
    y_values = [score for score in results[dim]['silhouette'].values() if score is not None]  # Ignore None values

    # Plot the Silhouette Score for each dimension
    plt.plot(x_values, y_values, marker='o', label=f'PCA {dim} dims')
    
    # Add labels with arrows pointing to the last point in each line
    if y_values:  # Check if y_values list is not empty
        plt.annotate(f'PCA {dim} dims',
                     xy=(x_values[-1], y_values[-1]),           # Last point coordinates
                     xytext=(x_values[-1] + 0.5, y_values[-1]), # Offset the text slightly
                     arrowprops=dict(arrowstyle="->", lw=1.5))

plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score vs Number of Clusters for Different PCA Dimensions')
plt.legend()
plt.grid(True)
plt.show()
